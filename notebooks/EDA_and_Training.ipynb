# %% [markdown]
# # Credit Risk — EDA and Model Training
#
# Run the production pipeline with:
#
# ```bash
# python -m src.train
# ```

# %%
import pandas as pd
from src.data_pipeline import preprocess_data, build_feature_matrix
from src.train import main

df = preprocess_data(save_cleaned=True)
print(f"Rows: {len(df):,}")
print(f"Default rate: {df['SeriousDlqin2yrs'].mean() * 100:.2f}%")
df.head()

# %%
main()
